# %%
import pandas as pd
pd.DataFrame(data={'a': [1]})

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_PATH = '/content/drive/My Drive/synthetic_image_detection/rule_based/'.replace(" ", "\\")

# %%
# %run {ROOT_PATH + 'fingerprint_generator.ipynb'}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define the lists of generative models
# generative_models_names = ['big_gan', 'cips', 'cycle_gan', 'ddpm', 'denoising_diffusion_gan', 'diffusion_gan', 'face_synthetics',
#                     'gansformer', 'gau_gan', 'generative_inpainting', 'glide', 'lama', 'latent_diffusion', 'mat', 'palette',
#                     'projected_gan', 'pro_gan', 'sfhq', 'stable_diffusion', 'star_gan', 'stylegan1', 'stylegan2', 'stylegan3',
#                     'taming_transformer', 'vq_diffusion']
generative_models_names = [(600, 'big_gan'),(265, 'stable_diffusion'), (20, 'cycle_gan')]

# %%
import pandas as pd
pd.DataFrame(data={'a': [1]})
# Out:
#    a
# 0  1

# %%
a= FingerprintGenerator(model_name='big_gan',  is_trained=True)
a.train_corr_f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-3a0ba3907d3d> in <cell line: 1>()
# ----> 1 a= FingerprintGenerator(model_name='big_gan',  is_trained=True)
#       2 a.train_corr_f
#
# <ipython-input-16-25d66262aa8c> in __init__(self, model_name, epoch, batch, is_trained)
#      12             hyperparams = pickle.load(pickle_file)
#      13         if is_trained:
# ---> 14           self.load_stats(Path(model_checkpoint_dir, 'chk_{}.pt'.format(epoch)))
#      15         hyperparams['Device'] = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      16         hyperparams['Batch Size'] = batch
#
# <ipython-input-16-25d66262aa8c> in load_stats(self, path)
#     378
#     379     def load_stats(self, path):
# --> 380         if self.device.type == 'cpu':
#     381             data_dict = torch.load(path, map_location=torch.device('cpu'))
# ...

# %%
X = []
y = []
generative_models = [FingerprintGenerator(model_name=model_name, is_trained=True, epoch=epoch) for epoch, model_name in generative_models_names] # create model instances
for index, model in enumerate(generative_models):
  train_corr_f = model.train_corr_f
  X.append([[corr] for corr in model.train_corr_f])
  y.extend([index] * len(model.train_corr_f))

# %%
X = [[0], [1], [2], [3]]
y = [0, 0, 1, 1]
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, y)
print(neigh.predict([[1.1]]))
print(neigh.predict_proba([[0.9]]))

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image from file
fake_image_to_detect_path = '/content/drive/My Drive/synthetic_image_detection/data/small_data/testing_data/synthetic_images/cycle_gan/img012099.jpg'


image_to_detect = mpimg.imread(fake_image_to_detect_path)

# Display the image
plt.imshow(image_to_detect)
plt.axis('off')  # Turn off axis labels
plt.title('Cycle Gan modle image')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=len(generative_models_names))
neigh.fit(X, y)
residuals = [model.denoise_image(fake_image_to_detect_path) for model in generative_models]
# correlations of the residual with each model fingerprint
correlations = [model.get_correlation(residual) for model, residual in zip(generative_models, residuals)]
# get the predicted probality for each model
predict_proba_models = [neigh.predict_proba([[corr]])[index] for index, corr in enumerate(correlations)]
max_predict_proba_models = max(predict_proba_models)
model_inex = predict_proba_models.index(max_predict_proba_models)
model_name = generative_models_names[model_inex]
model_name
